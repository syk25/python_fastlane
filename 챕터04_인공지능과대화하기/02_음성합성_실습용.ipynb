# %% [markdown]
# ___
# <a href='https://cafe.naver.com/jmhonglab'><p style="text-align:center;"><img src='https://lh3.googleusercontent.com/lY3ySXooSmwsq5r-mRi7uiypbo0Vez6pmNoQxMFhl9fmZJkRHu5lO2vo7se_0YOzgmDyJif9fi4_z0o3ZFdwd8NVSWG6Ea80uWaf3pOHpR4GHGDV7kaFeuHR3yAjIJjDgfXMxsvw=w2400'  class="center" width="50%" height="50%"/></p></a>
# ___
# <center><em>Content Copyright by HongLab, Inc.</em></center>

# %% [markdown]
# # 음성 합성
#
# 음성 합성은 음성 인식의 반대 과정을 거칩니다. 대표적인 기술로는 구글의 [타코트론](https://ai.googleblog.com/2017/12/tacotron-2-generating-human-like-speech.html)이 있습니다.
#
#
# ### [Google Text-to-Speech](https://github.com/pndurette/gTTS)
#
# 구글에서 제공해주는 음성 합성 패키지입니다. 인터넷이 연결되어 있어야 사용할 수 있습니다.
#
# ```
# pip install gtts
# pip install pydub
# ```
#
# 맥에서는 ffmpeg을 추가로 설치해야 합니다.
# ```
# brew install ffmpeg
# ```

# %% [markdown]
# 사용 가능한 언어들의 목록을 출력해보겠습니다.

# %%
import gtts

# print("사용 가능한 모든 언어들", gtts.lang.tts_langs())

# 영어와 한국어만 보기
# 딕트 컴프리헨션 (C언어 블럭과 혼동 주의)

{
    k: v
    for k, v in gtts.lang.tts_langs().items()
    if v.lower() == "korean" or v.lower() == "english"
}
# Out:
# {'en': 'English', 'ko': 'Korean'}

# %%
import gtts
from pydub import AudioSegment
from pydub.playback import play

# 텍스트를 음성으로 바꿉니다.
tts = gtts.gTTS("안녕하세요? 인공지능입니다.", lang="ko")

# mp3 파일로 저장합니다.
tts.save("temp.mp3")

# mp3 파일을 다시 읽어들입니다.
my_sound = AudioSegment.from_mp3("temp.mp3")


# 컴퓨터로 재생합니다.
play(my_sound)

# %% [markdown]
# 파일로 저장하지 않고 바로 재생하는 방법도 있습니다.

# %%
import gtts
from io import BytesIO
from pydub import AudioSegment
from pydub.playback import play

# 텍스트를 음성으로 바꿉니다.
tts = gtts.gTTS("안녕하세요? 인공지능입니다.", lang="ko")

# mp3 오디오 데이터를 메모리에 저장합니다.
fp = BytesIO()
tts.write_to_fp(fp)
fp = BytesIO(fp.getvalue())

# 오디오 데이터를 메모리로부터 가져옵니다.
my_sound = AudioSegment.from_file(fp, format="mp3")

# 컴퓨터로 재생합니다.
play(my_sound)

# %%
""" 음성합성기술 예외처리 """

import gtts
from io import BytesIO
from pydub import AudioSegment
from pydub.playback import play

# 텍스트를 음성으로 바꿉니다.
tts = gtts.gTTS("안녕하세요? 인공지능입니다.", lang="kr")

# mp3 오디오 데이터를 메모리에 저장합니다.
fp = BytesIO()
tts.write_to_fp(fp)
fp = BytesIO(fp.getvalue())

# 오디오 데이터를 메모리로부터 가져옵니다.
my_sound = AudioSegment.from_file(fp, format="mp3")

# 컴퓨터로 재생합니다.
play(my_sound)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 9
#       6 from pydub.playback import play
#       8 # 텍스트를 음성으로 바꿉니다.
# ----> 9 tts = gtts.gTTS("안녕하세요? 인공지능입니다.", lang="kr")
#      11 # mp3 오디오 데이터를 메모리에 저장합니다.
#      12 fp = BytesIO()
#
# File /opt/anaconda3/envs/fast_lane/lib/python3.10/site-packages/gtts/tts.py:150, in gTTS.__init__(self, text, tld, lang, slow, lang_check, pre_processor_funcs, tokenizer_func, timeout)
#     148     langs = tts_langs()
#     149     if self.lang not in langs:
# --> 150         raise ValueError("Language not supported: %s" % lang)
#     151 except RuntimeError as e:
#     152     log.debug(str(e), exc_info=True)
#
# ValueError: Language not supported: kr

# %% [markdown]
# [참고] ```gTTS()```와 ```write_to_ft()```의 문서를 참고해서 예외 처리를 할 수 있습니다.

# %% [markdown]
# ### [pyttsx3](https://github.com/nateshmbhat/pyttsx3)
#
#
# 운영체제에서 제공해주는 음성 합성 엔진을 사용하기 때문에 인터넷 연결 불필요
#
# - [SAPI5](https://en.wikipedia.org/wiki/Microsoft_Speech_API) on Windows
# - [NSSpeechSynthesizer](https://developer.apple.com/documentation/appkit/nsspeechsynthesizer) on Mac OS
#
# ```
# pip install pyttsx3
# ```
#
# 윈도우에서는 음성 설정에서 사용 가능한 언어를 추가할 수 있습니다.
# 맥에서는 accessibility -> spoken contents에서 사용 가능한 목소리를 추가할 수 있습니다.

# %% [markdown]
# 설치되어 있는 언어를 먼저 확인해봅시다.

# %%
import pyttsx3

engine = pyttsx3.init()

voices = engine.getProperty("voices")

for id, voice in enumerate(voices):
    print(id, voice)
# Out:
# 0 <Voice id=com.apple.speech.synthesis.voice.Albert
#           name=Albert
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 1 <Voice id=com.apple.voice.compact.it-IT.Alice
#           name=Alice
#           languages=['it_IT']
#           gender=VoiceGenderFemale
#           age=None>
# 2 <Voice id=com.apple.voice.compact.sv-SE.Alva
#           name=Alva
#           languages=['sv_SE']
#           gender=VoiceGenderFemale
#           age=None>
# 3 <Voice id=com.apple.voice.compact.fr-CA.Amelie
#           name=Amélie
#           languages=['fr_CA']
#           gender=VoiceGenderFemale
#           age=None>
# 4 <Voice id=com.apple.voice.compact.ms-MY.Amira
#           name=Amira
#           languages=['ms_MY']
#           gender=VoiceGenderFemale
#           age=None>
# 5 <Voice id=com.apple.voice.compact.de-DE.Anna
#           name=Anna
#           languages=['de_DE']
#           gender=VoiceGenderFemale
#           age=None>
# 6 <Voice id=com.apple.speech.synthesis.voice.BadNews
#           name=Bad News
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 7 <Voice id=com.apple.speech.synthesis.voice.Bahh
#           name=Bahh
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 8 <Voice id=com.apple.speech.synthesis.voice.Bells
#           name=Bells
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 9 <Voice id=com.apple.speech.synthesis.voice.Boing
#           name=Boing
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 10 <Voice id=com.apple.speech.synthesis.voice.Bubbles
#           name=Bubbles
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 11 <Voice id=com.apple.voice.compact.he-IL.Carmit
#           name=Carmit
#           languages=['he_IL']
#           gender=VoiceGenderFemale
#           age=None>
# 12 <Voice id=com.apple.speech.synthesis.voice.Cellos
#           name=Cellos
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 13 <Voice id=com.apple.voice.compact.id-ID.Damayanti
#           name=Damayanti
#           languages=['id_ID']
#           gender=VoiceGenderFemale
#           age=None>
# 14 <Voice id=com.apple.voice.compact.en-GB.Daniel
#           name=Daniel
#           languages=['en_GB']
#           gender=VoiceGenderMale
#           age=None>
# 15 <Voice id=com.apple.voice.compact.bg-BG.Daria
#           name=Daria
#           languages=['bg_BG']
#           gender=VoiceGenderFemale
#           age=None>
# 16 <Voice id=com.apple.speech.synthesis.voice.Deranged
#           name=Wobble
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 17 <Voice id=com.apple.eloquence.de-DE.Eddy
#           name=Eddy (German (Germany))
#           languages=['de_DE']
#           gender=VoiceGenderNeuter
#           age=None>
# 18 <Voice id=com.apple.eloquence.en-GB.Eddy
#           name=Eddy (English (UK))
#           languages=['en_GB']
#           gender=VoiceGenderNeuter
#           age=None>
# 19 <Voice id=com.apple.eloquence.en-US.Eddy
#           name=Eddy (English (US))
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 20 <Voice id=com.apple.eloquence.es-ES.Eddy
#           name=Eddy (Spanish (Spain))
#           languages=['es_ES']
#           gender=VoiceGenderNeuter
#           age=None>
# 21 <Voice id=com.apple.eloquence.es-MX.Eddy
#           name=Eddy (Spanish (Mexico))
#           languages=['es_MX']
#           gender=VoiceGenderNeuter
#           age=None>
# 22 <Voice id=com.apple.eloquence.fi-FI.Eddy
#           name=Eddy (Finnish (Finland))
#           languages=['fi_FI']
#           gender=VoiceGenderNeuter
#           age=None>
# 23 <Voice id=com.apple.eloquence.fr-CA.Eddy
#           name=Eddy (French (Canada))
#           languages=['fr_CA']
#           gender=VoiceGenderNeuter
#           age=None>
# 24 <Voice id=com.apple.eloquence.fr-FR.Eddy
#           name=Eddy (French (France))
#           languages=['fr_FR']
#           gender=VoiceGenderNeuter
#           age=None>
# 25 <Voice id=com.apple.eloquence.it-IT.Eddy
#           name=Eddy (Italian (Italy))
#           languages=['it_IT']
#           gender=VoiceGenderNeuter
#           age=None>
# 26 <Voice id=com.apple.eloquence.pt-BR.Eddy
#           name=Eddy (Portuguese (Brazil))
#           languages=['pt_BR']
#           gender=VoiceGenderNeuter
#           age=None>
# 27 <Voice id=com.apple.voice.compact.nl-BE.Ellen
#           name=Ellen
#           languages=['nl_BE']
#           gender=VoiceGenderFemale
#           age=None>
# 28 <Voice id=com.apple.eloquence.de-DE.Flo
#           name=Flo (German (Germany))
#           languages=['de_DE']
#           gender=VoiceGenderNeuter
#           age=None>
# 29 <Voice id=com.apple.eloquence.en-GB.Flo
#           name=Flo (English (UK))
#           languages=['en_GB']
#           gender=VoiceGenderNeuter
#           age=None>
# 30 <Voice id=com.apple.eloquence.en-US.Flo
#           name=Flo (English (US))
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 31 <Voice id=com.apple.eloquence.es-ES.Flo
#           name=Flo (Spanish (Spain))
#           languages=['es_ES']
#           gender=VoiceGenderNeuter
#           age=None>
# 32 <Voice id=com.apple.eloquence.es-MX.Flo
#           name=Flo (Spanish (Mexico))
#           languages=['es_MX']
#           gender=VoiceGenderNeuter
#           age=None>
# 33 <Voice id=com.apple.eloquence.fi-FI.Flo
#           name=Flo (Finnish (Finland))
#           languages=['fi_FI']
#           gender=VoiceGenderNeuter
#           age=None>
# 34 <Voice id=com.apple.eloquence.fr-CA.Flo
#           name=Flo (French (Canada))
#           languages=['fr_CA']
#           gender=VoiceGenderNeuter
#           age=None>
# 35 <Voice id=com.apple.eloquence.fr-FR.Flo
#           name=Flo (French (France))
#           languages=['fr_FR']
#           gender=VoiceGenderNeuter
#           age=None>
# 36 <Voice id=com.apple.eloquence.it-IT.Flo
#           name=Flo (Italian (Italy))
#           languages=['it_IT']
#           gender=VoiceGenderNeuter
#           age=None>
# 37 <Voice id=com.apple.eloquence.pt-BR.Flo
#           name=Flo (Portuguese (Brazil))
#           languages=['pt_BR']
#           gender=VoiceGenderNeuter
#           age=None>
# 38 <Voice id=com.apple.speech.synthesis.voice.Fred
#           name=Fred
#           languages=['en_US']
#           gender=VoiceGenderMale
#           age=None>
# 39 <Voice id=com.apple.speech.synthesis.voice.GoodNews
#           name=Good News
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 40 <Voice id=com.apple.eloquence.de-DE.Grandma
#           name=Grandma (German (Germany))
#           languages=['de_DE']
#           gender=VoiceGenderNeuter
#           age=None>
# 41 <Voice id=com.apple.eloquence.en-GB.Grandma
#           name=Grandma (English (UK))
#           languages=['en_GB']
#           gender=VoiceGenderNeuter
#           age=None>
# 42 <Voice id=com.apple.eloquence.en-US.Grandma
#           name=Grandma (English (US))
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 43 <Voice id=com.apple.eloquence.es-ES.Grandma
#           name=Grandma (Spanish (Spain))
#           languages=['es_ES']
#           gender=VoiceGenderNeuter
#           age=None>
# 44 <Voice id=com.apple.eloquence.es-MX.Grandma
#           name=Grandma (Spanish (Mexico))
#           languages=['es_MX']
#           gender=VoiceGenderNeuter
#           age=None>
# 45 <Voice id=com.apple.eloquence.fi-FI.Grandma
#           name=Grandma (Finnish (Finland))
#           languages=['fi_FI']
#           gender=VoiceGenderNeuter
#           age=None>
# 46 <Voice id=com.apple.eloquence.fr-CA.Grandma
#           name=Grandma (French (Canada))
#           languages=['fr_CA']
#           gender=VoiceGenderNeuter
#           age=None>
# 47 <Voice id=com.apple.eloquence.fr-FR.Grandma
#           name=Grandma (French (France))
#           languages=['fr_FR']
#           gender=VoiceGenderNeuter
#           age=None>
# 48 <Voice id=com.apple.eloquence.it-IT.Grandma
#           name=Grandma (Italian (Italy))
#           languages=['it_IT']
#           gender=VoiceGenderNeuter
#           age=None>
# 49 <Voice id=com.apple.eloquence.pt-BR.Grandma
#           name=Grandma (Portuguese (Brazil))
#           languages=['pt_BR']
#           gender=VoiceGenderNeuter
#           age=None>
# 50 <Voice id=com.apple.eloquence.de-DE.Grandpa
#           name=Grandpa (German (Germany))
#           languages=['de_DE']
#           gender=VoiceGenderNeuter
#           age=None>
# 51 <Voice id=com.apple.eloquence.en-GB.Grandpa
#           name=Grandpa (English (UK))
#           languages=['en_GB']
#           gender=VoiceGenderNeuter
#           age=None>
# 52 <Voice id=com.apple.eloquence.en-US.Grandpa
#           name=Grandpa (English (US))
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 53 <Voice id=com.apple.eloquence.es-ES.Grandpa
#           name=Grandpa (Spanish (Spain))
#           languages=['es_ES']
#           gender=VoiceGenderNeuter
#           age=None>
# 54 <Voice id=com.apple.eloquence.es-MX.Grandpa
#           name=Grandpa (Spanish (Mexico))
#           languages=['es_MX']
#           gender=VoiceGenderNeuter
#           age=None>
# 55 <Voice id=com.apple.eloquence.fi-FI.Grandpa
#           name=Grandpa (Finnish (Finland))
#           languages=['fi_FI']
#           gender=VoiceGenderNeuter
#           age=None>
# 56 <Voice id=com.apple.eloquence.fr-CA.Grandpa
#           name=Grandpa (French (Canada))
#           languages=['fr_CA']
#           gender=VoiceGenderNeuter
#           age=None>
# 57 <Voice id=com.apple.eloquence.fr-FR.Grandpa
#           name=Grandpa (French (France))
#           languages=['fr_FR']
#           gender=VoiceGenderNeuter
#           age=None>
# 58 <Voice id=com.apple.eloquence.it-IT.Grandpa
#           name=Grandpa (Italian (Italy))
#           languages=['it_IT']
#           gender=VoiceGenderNeuter
#           age=None>
# 59 <Voice id=com.apple.eloquence.pt-BR.Grandpa
#           name=Grandpa (Portuguese (Brazil))
#           languages=['pt_BR']
#           gender=VoiceGenderNeuter
#           age=None>
# 60 <Voice id=com.apple.speech.synthesis.voice.Hysterical
#           name=Jester
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 61 <Voice id=com.apple.voice.compact.ro-RO.Ioana
#           name=Ioana
#           languages=['ro_RO']
#           gender=VoiceGenderFemale
#           age=None>
# 62 <Voice id=com.apple.eloquence.fr-FR.Jacques
#           name=Jacques
#           languages=['fr_FR']
#           gender=VoiceGenderNeuter
#           age=None>
# 63 <Voice id=com.apple.voice.compact.pt-PT.Joana
#           name=Joana
#           languages=['pt_PT']
#           gender=VoiceGenderFemale
#           age=None>
# 64 <Voice id=com.apple.speech.synthesis.voice.Junior
#           name=Junior
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 65 <Voice id=com.apple.voice.compact.th-TH.Kanya
#           name=Kanya
#           languages=['th_TH']
#           gender=VoiceGenderFemale
#           age=None>
# 66 <Voice id=com.apple.voice.compact.en-AU.Karen
#           name=Karen
#           languages=['en_AU']
#           gender=VoiceGenderFemale
#           age=None>
# 67 <Voice id=com.apple.speech.synthesis.voice.Kathy
#           name=Kathy
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 68 <Voice id=com.apple.voice.compact.ja-JP.Kyoko
#           name=Kyoko
#           languages=['ja_JP']
#           gender=VoiceGenderFemale
#           age=None>
# 69 <Voice id=com.apple.voice.compact.hr-HR.Lana
#           name=Lana
#           languages=['hr_HR']
#           gender=VoiceGenderFemale
#           age=None>
# 70 <Voice id=com.apple.voice.compact.sk-SK.Laura
#           name=Laura
#           languages=['sk_SK']
#           gender=VoiceGenderFemale
#           age=None>
# 71 <Voice id=com.apple.voice.compact.hi-IN.Lekha
#           name=Lekha
#           languages=['hi_IN']
#           gender=VoiceGenderFemale
#           age=None>
# 72 <Voice id=com.apple.voice.compact.uk-UA.Lesya
#           name=Lesya
#           languages=['uk_UA']
#           gender=VoiceGenderFemale
#           age=None>
# 73 <Voice id=com.apple.voice.compact.vi-VN.Linh
#           name=Linh
#           languages=['vi_VN']
#           gender=VoiceGenderFemale
#           age=None>
# 74 <Voice id=com.apple.voice.compact.pt-BR.Luciana
#           name=Luciana
#           languages=['pt_BR']
#           gender=VoiceGenderFemale
#           age=None>
# 75 <Voice id=com.apple.voice.compact.ar-001.Maged
#           name=Majed
#           languages=['ar_001']
#           gender=VoiceGenderMale
#           age=None>
# 76 <Voice id=com.apple.voice.compact.hu-HU.Mariska
#           name=Tünde
#           languages=['hu_HU']
#           gender=VoiceGenderFemale
#           age=None>
# 77 <Voice id=com.apple.voice.compact.zh-TW.Meijia
#           name=Meijia
#           languages=['zh_TW']
#           gender=VoiceGenderFemale
#           age=None>
# 78 <Voice id=com.apple.voice.compact.el-GR.Melina
#           name=Melina
#           languages=['el_GR']
#           gender=VoiceGenderFemale
#           age=None>
# 79 <Voice id=com.apple.voice.compact.ru-RU.Milena
#           name=Milena
#           languages=['ru_RU']
#           gender=VoiceGenderFemale
#           age=None>
# 80 <Voice id=com.apple.voice.compact.en-IE.Moira
#           name=Moira
#           languages=['en_IE']
#           gender=VoiceGenderFemale
#           age=None>
# 81 <Voice id=com.apple.voice.compact.es-ES.Monica
#           name=Mónica
#           languages=['es_ES']
#           gender=VoiceGenderFemale
#           age=None>
# 82 <Voice id=com.apple.voice.compact.ca-ES.Montserrat
#           name=Montse
#           languages=['ca_ES']
#           gender=VoiceGenderFemale
#           age=None>
# 83 <Voice id=com.apple.voice.compact.nb-NO.Nora
#           name=Nora
#           languages=['nb_NO']
#           gender=VoiceGenderFemale
#           age=None>
# 84 <Voice id=com.apple.speech.synthesis.voice.Organ
#           name=Organ
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 85 <Voice id=com.apple.voice.compact.es-MX.Paulina
#           name=Paulina
#           languages=['es_MX']
#           gender=VoiceGenderFemale
#           age=None>
# 86 <Voice id=com.apple.speech.synthesis.voice.Princess
#           name=Superstar
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 87 <Voice id=com.apple.speech.synthesis.voice.Ralph
#           name=Ralph
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 88 <Voice id=com.apple.eloquence.de-DE.Reed
#           name=Reed (German (Germany))
#           languages=['de_DE']
#           gender=VoiceGenderNeuter
#           age=None>
# 89 <Voice id=com.apple.eloquence.en-GB.Reed
#           name=Reed (English (UK))
#           languages=['en_GB']
#           gender=VoiceGenderNeuter
#           age=None>
# 90 <Voice id=com.apple.eloquence.en-US.Reed
#           name=Reed (English (US))
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 91 <Voice id=com.apple.eloquence.es-ES.Reed
#           name=Reed (Spanish (Spain))
#           languages=['es_ES']
#           gender=VoiceGenderNeuter
#           age=None>
# 92 <Voice id=com.apple.eloquence.es-MX.Reed
#           name=Reed (Spanish (Mexico))
#           languages=['es_MX']
#           gender=VoiceGenderNeuter
#           age=None>
# 93 <Voice id=com.apple.eloquence.fi-FI.Reed
#           name=Reed (Finnish (Finland))
#           languages=['fi_FI']
#           gender=VoiceGenderNeuter
#           age=None>
# 94 <Voice id=com.apple.eloquence.fr-CA.Reed
#           name=Reed (French (Canada))
#           languages=['fr_CA']
#           gender=VoiceGenderNeuter
#           age=None>
# 95 <Voice id=com.apple.eloquence.it-IT.Reed
#           name=Reed (Italian (Italy))
#           languages=['it_IT']
#           gender=VoiceGenderNeuter
#           age=None>
# 96 <Voice id=com.apple.eloquence.pt-BR.Reed
#           name=Reed (Portuguese (Brazil))
#           languages=['pt_BR']
#           gender=VoiceGenderNeuter
#           age=None>
# 97 <Voice id=com.apple.voice.compact.en-IN.Rishi
#           name=Rishi
#           languages=['en_IN']
#           gender=VoiceGenderMale
#           age=None>
# 98 <Voice id=com.apple.eloquence.de-DE.Rocko
#           name=Rocko (German (Germany))
#           languages=['de_DE']
#           gender=VoiceGenderNeuter
#           age=None>
# 99 <Voice id=com.apple.eloquence.en-GB.Rocko
#           name=Rocko (English (UK))
#           languages=['en_GB']
#           gender=VoiceGenderNeuter
#           age=None>
# 100 <Voice id=com.apple.eloquence.en-US.Rocko
#           name=Rocko (English (US))
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 101 <Voice id=com.apple.eloquence.es-ES.Rocko
#           name=Rocko (Spanish (Spain))
#           languages=['es_ES']
#           gender=VoiceGenderNeuter
#           age=None>
# 102 <Voice id=com.apple.eloquence.es-MX.Rocko
#           name=Rocko (Spanish (Mexico))
#           languages=['es_MX']
#           gender=VoiceGenderNeuter
#           age=None>
# 103 <Voice id=com.apple.eloquence.fi-FI.Rocko
#           name=Rocko (Finnish (Finland))
#           languages=['fi_FI']
#           gender=VoiceGenderNeuter
#           age=None>
# 104 <Voice id=com.apple.eloquence.fr-CA.Rocko
#           name=Rocko (French (Canada))
#           languages=['fr_CA']
#           gender=VoiceGenderNeuter
#           age=None>
# 105 <Voice id=com.apple.eloquence.fr-FR.Rocko
#           name=Rocko (French (France))
#           languages=['fr_FR']
#           gender=VoiceGenderNeuter
#           age=None>
# 106 <Voice id=com.apple.eloquence.it-IT.Rocko
#           name=Rocko (Italian (Italy))
#           languages=['it_IT']
#           gender=VoiceGenderNeuter
#           age=None>
# 107 <Voice id=com.apple.eloquence.pt-BR.Rocko
#           name=Rocko (Portuguese (Brazil))
#           languages=['pt_BR']
#           gender=VoiceGenderNeuter
#           age=None>
# 108 <Voice id=com.apple.voice.compact.en-US.Samantha
#           name=Samantha
#           languages=['en_US']
#           gender=VoiceGenderFemale
#           age=None>
# 109 <Voice id=com.apple.eloquence.de-DE.Sandy
#           name=Sandy (German (Germany))
#           languages=['de_DE']
#           gender=VoiceGenderNeuter
#           age=None>
# 110 <Voice id=com.apple.eloquence.en-GB.Sandy
#           name=Sandy (English (UK))
#           languages=['en_GB']
#           gender=VoiceGenderNeuter
#           age=None>
# 111 <Voice id=com.apple.eloquence.en-US.Sandy
#           name=Sandy (English (US))
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 112 <Voice id=com.apple.eloquence.es-ES.Sandy
#           name=Sandy (Spanish (Spain))
#           languages=['es_ES']
#           gender=VoiceGenderNeuter
#           age=None>
# 113 <Voice id=com.apple.eloquence.es-MX.Sandy
#           name=Sandy (Spanish (Mexico))
#           languages=['es_MX']
#           gender=VoiceGenderNeuter
#           age=None>
# 114 <Voice id=com.apple.eloquence.fi-FI.Sandy
#           name=Sandy (Finnish (Finland))
#           languages=['fi_FI']
#           gender=VoiceGenderNeuter
#           age=None>
# 115 <Voice id=com.apple.eloquence.fr-CA.Sandy
#           name=Sandy (French (Canada))
#           languages=['fr_CA']
#           gender=VoiceGenderNeuter
#           age=None>
# 116 <Voice id=com.apple.eloquence.fr-FR.Sandy
#           name=Sandy (French (France))
#           languages=['fr_FR']
#           gender=VoiceGenderNeuter
#           age=None>
# 117 <Voice id=com.apple.eloquence.it-IT.Sandy
#           name=Sandy (Italian (Italy))
#           languages=['it_IT']
#           gender=VoiceGenderNeuter
#           age=None>
# 118 <Voice id=com.apple.eloquence.pt-BR.Sandy
#           name=Sandy (Portuguese (Brazil))
#           languages=['pt_BR']
#           gender=VoiceGenderNeuter
#           age=None>
# 119 <Voice id=com.apple.voice.compact.da-DK.Sara
#           name=Sara
#           languages=['da_DK']
#           gender=VoiceGenderFemale
#           age=None>
# 120 <Voice id=com.apple.voice.compact.fi-FI.Satu
#           name=Satu
#           languages=['fi_FI']
#           gender=VoiceGenderFemale
#           age=None>
# 121 <Voice id=com.apple.eloquence.de-DE.Shelley
#           name=Shelley (German (Germany))
#           languages=['de_DE']
#           gender=VoiceGenderNeuter
#           age=None>
# 122 <Voice id=com.apple.eloquence.en-GB.Shelley
#           name=Shelley (English (UK))
#           languages=['en_GB']
#           gender=VoiceGenderNeuter
#           age=None>
# 123 <Voice id=com.apple.eloquence.en-US.Shelley
#           name=Shelley (English (US))
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 124 <Voice id=com.apple.eloquence.es-ES.Shelley
#           name=Shelley (Spanish (Spain))
#           languages=['es_ES']
#           gender=VoiceGenderNeuter
#           age=None>
# 125 <Voice id=com.apple.eloquence.es-MX.Shelley
#           name=Shelley (Spanish (Mexico))
#           languages=['es_MX']
#           gender=VoiceGenderNeuter
#           age=None>
# 126 <Voice id=com.apple.eloquence.fi-FI.Shelley
#           name=Shelley (Finnish (Finland))
#           languages=['fi_FI']
#           gender=VoiceGenderNeuter
#           age=None>
# 127 <Voice id=com.apple.eloquence.fr-CA.Shelley
#           name=Shelley (French (Canada))
#           languages=['fr_CA']
#           gender=VoiceGenderNeuter
#           age=None>
# 128 <Voice id=com.apple.eloquence.fr-FR.Shelley
#           name=Shelley (French (France))
#           languages=['fr_FR']
#           gender=VoiceGenderNeuter
#           age=None>
# 129 <Voice id=com.apple.eloquence.it-IT.Shelley
#           name=Shelley (Italian (Italy))
#           languages=['it_IT']
#           gender=VoiceGenderNeuter
#           age=None>
# 130 <Voice id=com.apple.eloquence.pt-BR.Shelley
#           name=Shelley (Portuguese (Brazil))
#           languages=['pt_BR']
#           gender=VoiceGenderNeuter
#           age=None>
# 131 <Voice id=com.apple.voice.compact.zh-HK.Sinji
#           name=Sinji
#           languages=['zh_HK']
#           gender=VoiceGenderFemale
#           age=None>
# 132 <Voice id=com.apple.voice.compact.en-ZA.Tessa
#           name=Tessa
#           languages=['en_ZA']
#           gender=VoiceGenderFemale
#           age=None>
# 133 <Voice id=com.apple.voice.compact.fr-FR.Thomas
#           name=Thomas
#           languages=['fr_FR']
#           gender=VoiceGenderMale
#           age=None>
# 134 <Voice id=com.apple.voice.compact.zh-CN.Tingting
#           name=Tingting
#           languages=['zh_CN']
#           gender=VoiceGenderFemale
#           age=None>
# 135 <Voice id=com.apple.speech.synthesis.voice.Trinoids
#           name=Trinoids
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 136 <Voice id=com.apple.speech.synthesis.voice.Whisper
#           name=Whisper
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 137 <Voice id=com.apple.voice.compact.nl-NL.Xander
#           name=Xander
#           languages=['nl_NL']
#           gender=VoiceGenderMale
#           age=None>
# 138 <Voice id=com.apple.voice.compact.tr-TR.Yelda
#           name=Yelda
#           languages=['tr_TR']
#           gender=VoiceGenderFemale
#           age=None>
# 139 <Voice id=com.apple.voice.compact.ko-KR.Yuna
#           name=Yuna
#           languages=['ko_KR']
#           gender=VoiceGenderFemale
#           age=None>
# 140 <Voice id=com.apple.speech.synthesis.voice.Zarvox
#           name=Zarvox
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# 141 <Voice id=com.apple.voice.compact.pl-PL.Zosia
#           name=Zosia
#           languages=['pl_PL']
#           gender=VoiceGenderFemale
#           age=None>
# 142 <Voice id=com.apple.voice.compact.cs-CZ.Zuzana
#           name=Zuzana
#           languages=['cs_CZ']
#           gender=VoiceGenderFemale
#           age=None>

# %% [markdown]
# 기본적인 재생 방법은 다음과 같습니다.

# %%
import pyttsx3

engine = pyttsx3.init()

engine.say("안녕하세요? 인공지능입니다.")

engine.runAndWait()

# %% [markdown]
# 더 간단하게 사용할 수도 있습니다.

# %%
import pyttsx3

# 더 간단한 방법
pyttsx3.speak("안녕하세요? 인공지능입니다.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 4
#       1 import pyttsx3
#       3 # 더 간단한 방법
# ----> 4 pyttsx3.speak("안녕하세요? 인공지능입니다.")
#
# AttributeError: module 'pyttsx3' has no attribute 'speak'

# %% [markdown]
# 그 외에도 말하는 속도, 소리 크기, 목소리(언어) 등을 바꿀 수 있습니다.

# %%
# 여러가지 속성 바꾸기
import pyttsx3

engine = pyttsx3.init()

# 말하는 속도
engine.setProperty("rate", 200)
rate = engine.getProperty("rate")

# 소리 크기
engine.setProperty("volume", 1.0)  # 0~1
volume = engine.getProperty("volume")

# 목소리
voices = engine.getProperty("voices")
engine.setProperty("voice", voices[20].id)  # 한국어 목소리가 아니라면 그대로 넘어간다

# 말하기
engine.say("12345")
engine.say("안녕하세요? 홍정모입니다.")
engine.say("I will speak this text")
engine.runAndWait()
engine.stop()

# %% [markdown]
# ### [Naver Cloud Platform](https://www.ncloud.com/)
#
# 비공식 API [NaverTTS](https://github.com/scottgigante/NaverTTS) Unofficial Python API for NAVER [Papago TTS](https://papago.naver.com/)
#
# [클로바 스피치 가격](https://www.ncloud.com/product/aiService/clovaSpeech)
#
# ```
# pip install NaverTTS
# ```

# %%
from io import BytesIO
from navertts import NaverTTS

from pydub import AudioSegment
from pydub.playback import play

# 음성파일 생성
tts = NaverTTS("안녕하세요? 인공지능입니다.", lang="ko")

# 음성파일을 메모리에 저장
fp = BytesIO()
tts.write_to_fp(fp)

# 메모리에서 음성파일 가져오기
fp = BytesIO(fp.getvalue())

# 음성파일 재생
my_sound = AudioSegment.from_file(fp, format="mp3")
play(my_sound)
